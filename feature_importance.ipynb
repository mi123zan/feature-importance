# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Check the working directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\MY\\Desktop\\Machine_learning\\drought'

# %% [markdown]
# # Read the data

# %%
data = pd.read_csv('dataset.csv', encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0                 55.10           209.79            967.32     28.08
# 1                 54.94           216.88            969.33     28.19
# 2                 54.82           223.18            970.23     27.63
# 3                 55.93           244.27            956.82     27.69
# 4                 54.86           229.52            969.02     26.80
#
#    relative humidi  elevation  distance from river  river density  \
# 0            78.53         11                 0.15           0.00
# 1            78.51         13                 0.11           0.00
# 2            78.48         14                 0.08           0.00
# 3            78.36          7                 0.03           0.10
# 4            78.44         16                 0.04           2.47
#
#    water level         LULC  ndvi  ndwi  slope  distance from road  \
# 0         4.31        Crops  0.32  0.19   0.34                0.02
# ...

# %% [markdown]
# # String convert to number using labelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['LULC']= encoder.fit_transform(data['LULC'])
data['Geology']=encoder.fit_transform(data['Geology'])
data['Soil moisture']=encoder.fit_transform(data['Soil moisture'])
data['soil texture']= encoder.fit_transform(data['soil texture'])

data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0                 55.10           209.79            967.32     28.08
# 1                 54.94           216.88            969.33     28.19
# 2                 54.82           223.18            970.23     27.63
# 3                 55.93           244.27            956.82     27.69
# 4                 54.86           229.52            969.02     26.80
#
#    relative humidi  elevation  distance from river  river density  \
# 0            78.53         11                 0.15           0.00
# 1            78.51         13                 0.11           0.00
# 2            78.48         14                 0.08           0.00
# 3            78.36          7                 0.03           0.10
# 4            78.44         16                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   % of irrigation land  1449 non-null   float64
#  1   % of deeptubewe       1449 non-null   float64
#  2   population (km2)      1449 non-null   float64
#  3   LST (0C)              1449 non-null   float64
#  4   relative humidi       1449 non-null   float64
#  5   elevation             1449 non-null   int64
#  6   distance from river   1449 non-null   float64
#  7   river density         1449 non-null   float64
#  8   water level           1449 non-null   float64
#  9   LULC                  1449 non-null   int32
#  10  ndvi                  1449 non-null   float64
#  11  ndwi                  1449 non-null   float64
#  12  slope                 1449 non-null   float64
#  13  distance from road    1449 non-null   float64
# ...

# %% [markdown]
# # Data scaling (normalization)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
scaled_1 = minmax.fit(data[['% of irrigation land']])

# %%
scaled_1
# Out:
# MinMaxScaler()

# %%
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0                 55.10           209.79            967.32     28.08
# 1                 54.94           216.88            969.33     28.19
# 2                 54.82           223.18            970.23     27.63
# 3                 55.93           244.27            956.82     27.69
# 4                 54.86           229.52            969.02     26.80
#
#    relative humidi  elevation  distance from river  river density  \
# 0            78.53         11                 0.15           0.00
# 1            78.51         13                 0.11           0.00
# 2            78.48         14                 0.08           0.00
# 3            78.36          7                 0.03           0.10
# 4            78.44         16                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
data['% of irrigation land'] = minmax.transform(data[['% of irrigation land']])

# %%
scaled_1 = minmax.fit(data[['% of irrigation land']])
data['% of irrigation land'] = minmax.transform(data[['% of irrigation land']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190           209.79            967.32     28.08
# 1              0.693520           216.88            969.33     28.19
# 2              0.690018           223.18            970.23     27.63
# 3              0.722417           244.27            956.82     27.69
# 4              0.691185           229.52            969.02     26.80
#
#    relative humidi  elevation  distance from river  river density  \
# 0            78.53         11                 0.15           0.00
# 1            78.51         13                 0.11           0.00
# 2            78.48         14                 0.08           0.00
# 3            78.36          7                 0.03           0.10
# 4            78.44         16                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_2 = minmax.fit(data[['% of deeptubewe']])
data['% of deeptubewe'] = minmax.transform(data[['% of deeptubewe']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389            967.32     28.08
# 1              0.693520         0.578023            969.33     28.19
# 2              0.690018         0.595470            970.23     27.63
# 3              0.722417         0.653873            956.82     27.69
# 4              0.691185         0.613027            969.02     26.80
#
#    relative humidi  elevation  distance from river  river density  \
# 0            78.53         11                 0.15           0.00
# 1            78.51         13                 0.11           0.00
# 2            78.48         14                 0.08           0.00
# 3            78.36          7                 0.03           0.10
# 4            78.44         16                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_3 = minmax.fit(data[['population (km2)']])
data['population (km2)'] = minmax.transform(data[['population (km2)']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003     28.08
# 1              0.693520         0.578023          0.432571     28.19
# 2              0.690018         0.595470          0.434168     27.63
# 3              0.722417         0.653873          0.410363     27.69
# 4              0.691185         0.613027          0.432020     26.80
#
#    relative humidi  elevation  distance from river  river density  \
# 0            78.53         11                 0.15           0.00
# 1            78.51         13                 0.11           0.00
# 2            78.48         14                 0.08           0.00
# 3            78.36          7                 0.03           0.10
# 4            78.44         16                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_4 = minmax.fit(data[['LST (0C)']])
data['LST (0C)'] = minmax.transform(data[['LST (0C)']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0            78.53         11                 0.15           0.00
# 1            78.51         13                 0.11           0.00
# 2            78.48         14                 0.08           0.00
# 3            78.36          7                 0.03           0.10
# 4            78.44         16                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_5 = minmax.fit(data[['relative humidi']])
data['relative humidi'] = minmax.transform(data[['relative humidi']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838         11                 0.15           0.00
# 1         0.877462         13                 0.11           0.00
# 2         0.870897         14                 0.08           0.00
# 3         0.844639          7                 0.03           0.10
# 4         0.862144         16                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_6 = minmax.fit(data[['Target']])
data['Target'] = minmax.transform(data[['Target']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838         11                 0.15           0.00
# 1         0.877462         13                 0.11           0.00
# 2         0.870897         14                 0.08           0.00
# 3         0.844639          7                 0.03           0.10
# 4         0.862144         16                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_7 = minmax.fit(data[['elevation']])
data['elevation'] = minmax.transform(data[['elevation']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15           0.00
# 1         0.877462   0.136364                 0.11           0.00
# 2         0.870897   0.147727                 0.08           0.00
# 3         0.844639   0.068182                 0.03           0.10
# 4         0.862144   0.170455                 0.04           2.47
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_8 = minmax.fit(data[['river density']])
data['river density'] = minmax.transform(data[['river density']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0         4.31     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_9 = minmax.fit(data[['water level']])
data['water level'] = minmax.transform(data[['water level']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level  LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0        0.905     2  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_10 = minmax.fit(data[['LULC']])
data['LULC'] = minmax.transform(data[['LULC']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level      LULC  ndvi  ndwi  slope  distance from road  Geology  \
# 0        0.905  0.333333  0.32  0.19   0.34                0.02        3
# ...

# %%
scaled_11 = minmax.fit(data[['slope']])
data['slope'] = minmax.transform(data[['slope']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level      LULC  ndvi  ndwi     slope  distance from road  Geology  \
# ...

# %%
scaled_12 = minmax.fit(data[['Geology']])
data['Geology'] = minmax.transform(data[['Geology']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level      LULC  ndvi  ndwi     slope  distance from road  Geology  \
# ...

# %%
scaled_13 = minmax.fit(data[['Soil moisture']])
data['Soil moisture'] = minmax.transform(data[['Soil moisture']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level      LULC  ndvi  ndwi     slope  distance from road  Geology  \
# ...

# %%
scaled_14 = minmax.fit(data[['soil texture']])
data['soil texture'] = minmax.transform(data[['soil texture']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level      LULC  ndvi  ndwi     slope  distance from road  Geology  \
# ...

# %%
scaled_15 = minmax.fit(data[['evapotranspiration']])
data['evapotranspiration'] = minmax.transform(data[['evapotranspiration']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level      LULC  ndvi  ndwi     slope  distance from road  Geology  \
# ...

# %%
scaled_17 = minmax.fit(data[['agri dep_popu']])
data['agri dep_popu'] = minmax.transform(data[['agri dep_popu']])
data.head()
# Out:
#    % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0              0.698190         0.558389          0.429003  0.644195
# 1              0.693520         0.578023          0.432571  0.657928
# 2              0.690018         0.595470          0.434168  0.588015
# 3              0.722417         0.653873          0.410363  0.595506
# 4              0.691185         0.613027          0.432020  0.484395
#
#    relative humidi  elevation  distance from river  river density  \
# 0         0.881838   0.113636                 0.15       0.000000
# 1         0.877462   0.136364                 0.11       0.000000
# 2         0.870897   0.147727                 0.08       0.000000
# 3         0.844639   0.068182                 0.03       0.002404
# 4         0.862144   0.170455                 0.04       0.059389
#
#    water level      LULC  ndvi  ndwi     slope  distance from road  Geology  \
# ...

# %% [markdown]
# # Save preprocessing data in csvfile

# %%
data.to_csv('scaled_19.csv')

# %%
data
# Out:
#       % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0                 0.698190         0.558389          0.429003  0.644195
# 1                 0.693520         0.578023          0.432571  0.657928
# 2                 0.690018         0.595470          0.434168  0.588015
# 3                 0.722417         0.653873          0.410363  0.595506
# 4                 0.691185         0.613027          0.432020  0.484395
# ...                    ...              ...               ...       ...
# 1444              0.264156         0.118607          0.145936  0.347066
# 1445              0.232925         0.107446          0.137468  0.304619
# 1446              0.204028         0.097200          0.129622  0.607990
# 1447              0.180969         0.088782          0.123675  0.466916
# 1448              0.167250         0.083243          0.121510  0.441948
#
#       relative humidi  elevation  distance from river  river density  \
# ...

# %% [markdown]
# # Load normalization data

# %%
data = pd.read_csv('scaled_18.csv', encoding = "ISO-8859-1")

# %%
data
# Out:
#       Unnamed: 0  % of irrigation land  % of deeptubewe  population (km2)  \
# 0              0              0.698190         0.558389          0.429003
# 1              1              0.693520         0.578023          0.432571
# 2              2              0.690018         0.595470          0.434168
# 3              3              0.722417         0.653873          0.410363
# 4              4              0.691185         0.613027          0.432020
# ...          ...                   ...              ...               ...
# 1444        1444              0.264156         0.118607          0.145936
# 1445        1445              0.232925         0.107446          0.137468
# 1446        1446              0.204028         0.097200          0.129622
# 1447        1447              0.180969         0.088782          0.123675
# 1448        1448              0.167250         0.083243          0.121510
#
#       LST (0C)  relative humidi  elevation  distance from river  \
# ...

# %%
data = data.drop('Unnamed: 0', axis=1)

# %%
data
# Out:
#       % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0                 0.698190         0.558389          0.429003  0.644195
# 1                 0.693520         0.578023          0.432571  0.657928
# 2                 0.690018         0.595470          0.434168  0.588015
# 3                 0.722417         0.653873          0.410363  0.595506
# 4                 0.691185         0.613027          0.432020  0.484395
# ...                    ...              ...               ...       ...
# 1444              0.264156         0.118607          0.145936  0.347066
# 1445              0.232925         0.107446          0.137468  0.304619
# 1446              0.204028         0.097200          0.129622  0.607990
# 1447              0.180969         0.088782          0.123675  0.466916
# 1448              0.167250         0.083243          0.121510  0.441948
#
#       relative humidi  elevation  distance from river  river density  \
# ...

# %%
####..................######

# %% [markdown]
# # Define X and Y datasets

# %%
Y=data.Target
X=data.drop('Target',axis=1)

# %%
Y
# Out:
# 0       0.535484
# 1       0.538609
# 2       0.544688
# 3       0.571552
# 4       0.552719
#           ...
# 1444    0.343019
# 1445    0.342341
# 1446    0.342148
# 1447    0.342462
# 1448    0.343304
# Name: Target, Length: 1449, dtype: float64

# %%
X
# Out:
#       % of irrigation land  % of deeptubewe  population (km2)  LST (0C)  \
# 0                 0.698190         0.558389          0.429003  0.644195
# 1                 0.693520         0.578023          0.432571  0.657928
# 2                 0.690018         0.595470          0.434168  0.588015
# 3                 0.722417         0.653873          0.410363  0.595506
# 4                 0.691185         0.613027          0.432020  0.484395
# ...                    ...              ...               ...       ...
# 1444              0.264156         0.118607          0.145936  0.347066
# 1445              0.232925         0.107446          0.137468  0.304619
# 1446              0.204028         0.097200          0.129622  0.607990
# 1447              0.180969         0.088782          0.123675  0.466916
# 1448              0.167250         0.083243          0.121510  0.441948
#
#       relative humidi  elevation  distance from river  river density  \
# ...

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier 
from matplotlib import pyplot as plt

# %%
model = XGBClassifier() 
model.fit(X, Y) 
print(model.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14172/4068492649.py in <module>
#       1 model = XGBClassifier()
# ----> 2 model.fit(X, Y)
#       3 print(model.feature_importances_)
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     530         for k, arg in zip(sig.parameters, args):
#     531             kwargs[k] = arg
# --> 532         return f(**kwargs)
#     533
#     534     return inner_f
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1355             or not (self.classes_ == expected_classes).all()
#    1356         ):
# -> 1357             raise ValueError(
# ...
